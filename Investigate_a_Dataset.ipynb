# %% [markdown]
# > **Tip**: Welcome to the Investigate a Dataset project! You will find tips in quoted sections like this to help organize your approach to your investigation. Once you complete this project, remove these **Tip** sections from your report before submission. First things first, you might want to double-click this Markdown cell and change the title so that it reflects your dataset and investigation.
#
# # Project: Investigate a Dataset - [Dataset-name]
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# ### Dataset Description
#
# > **Tip**: In this section of the report, provide a brief introduction to the dataset you've selected/downloaded for analysis. Read through the description available on the homepage-links present [here](https://docs.google.com/document/d/e/2PACX-1vTlVmknRRnfy_4eTrjw5hYGaiQim5ctr9naaRd4V9du2B5bxpd8FEH3KtDgp8qVekw7Cj1GLk1IXdZi/pub?embedded=True). List all column names in each table, and their significance. In case of multiple tables, describe the relationship between tables.
#
#
# ### Question(s) for Analysis
# >**Tip**: Clearly state one or more questions that you plan on exploring over the course of the report. You will address these questions in the **data analysis** and **conclusion** sections. Try to build your report around the analysis of at least one dependent variable and three independent variables. If you're not sure what questions to ask, then make sure you familiarize yourself with the dataset, its variables and the dataset context for ideas of what to explore.
#
# > **Tip**: Once you start coding, use NumPy arrays, Pandas Series, and DataFrames where appropriate rather than Python lists and dictionaries. Also, **use good coding practices**, such as, define and use functions to avoid repetitive code. Use appropriate comments within the code cells, explanation in the mark-down cells, and meaningful variable names.

# %% [markdown]
# #  Research Question :
#      1-What is the the original title of the Movie with Maximum and Minimum budget?¶
#      2-What is the the original title of the Movie with Maximum and Minimum revenue?
#      3-What is the the original title of the Movie with Maximum and Minimum profit?
#      4-What is the the original title of the Movie with Maximum and Minimum runtime?
#      5-Which genre has the highest and lowest number of movies ?
#      6-Which cast has the highest number of movies ?
#      7-Is the number of movies increases or decrease over years?
#      8-Is the profit increases or decreases over years?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# > **Tip**: In this section of the report, you will load in the data, check for cleanliness, and then trim and clean your dataset for analysis. Make sure that you **document your data cleaning steps in mark-down cells precisely and justify your cleaning decisions.**
#
#
# ### General Properties
# > **Tip**: You should _not_ perform too many operations in each cell. Create cells freely to explore your data. One option that you can take with this project is to do a lot of explorations in an initial notebook. These don't have to be organized, but make sure you use enough comments to understand the purpose of each code cell. Then, after you're done with your analysis, create a duplicate notebook where you will trim the excess and organize your steps so that you have a flowing, cohesive report.

# %%
#load Data
df = pd.read_csv('tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
#print number of columns and rows in the Dataset
df.shape
# Out:
# (10866, 21)

# %%
#print describtion data for each column in rhe dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# ...

# %% [markdown]
# ### Data Cleaning
# > **Tip**: Make sure that you keep your reader informed on the steps that you are taking in your investigation. Follow every code cell, or every set of related code cells, with a markdown cell to describe to the reader what was found in the preceding cell(s). Try to make it so that the reader can then understand what they will be seeing in the following cell(s).

# %%
# Drop the unused columns from the Dataset
df.drop(['id','imdb_id','popularity','homepage','keywords','overview','production_companies','vote_count','vote_average','budget_adj','revenue_adj'] , axis = 1, inplace = True)
df.head()
# Out:
#       budget     revenue                original_title  \
# 0  150000000  1513528810                Jurassic World
# 1  150000000   378436354            Mad Max: Fury Road
# 2  110000000   295238201                     Insurgent
# 3  200000000  2068178225  Star Wars: The Force Awakens
# 4  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime  \
# 0              The park is open.      124
# 1             What a Lovely Day.      120
# 2     One Choice Can Destroy You      119
# ...

# %%
#check if there is any duplicated rows
df.duplicated().any()
# Out:
# True

# %%
# Drop the duplicated rows but keep only the last duplicated row
df.drop_duplicates(keep='last' , inplace = True)
#again,check if there is any dplicated rows
df.duplicated().any()
# Out:
# False

# %%
# Drop any null values
df.dropna(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8001 entries, 0 to 10865
# Data columns (total 10 columns):
# budget            8001 non-null int64
# revenue           8001 non-null int64
# original_title    8001 non-null object
# cast              8001 non-null object
# director          8001 non-null object
# tagline           8001 non-null object
# runtime           8001 non-null int64
# genres            8001 non-null object
# release_date      8001 non-null object
# release_year      8001 non-null int64
# dtypes: int64(4), object(6)
# memory usage: 687.6+ KB

# %%
df.head()
# Out:
#       budget     revenue                original_title  \
# 0  150000000  1513528810                Jurassic World
# 1  150000000   378436354            Mad Max: Fury Road
# 2  110000000   295238201                     Insurgent
# 3  200000000  2068178225  Star Wars: The Force Awakens
# 4  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime  \
# 0              The park is open.      124
# 1             What a Lovely Day.      120
# 2     One Choice Can Destroy You      119
# ...

# %%
#print number of rows with budget's value less than or equal to zero
df[df.budget<=0].shape[0]
# Out:
# 3454

# %%
#Keep only the rows with budget's value greater than zero
df = df[df.budget>0]

# %%
#Keep only the rows with revenue's value greater than zero
df = df[df.revenue>0]
##print number of rows with revenue's value less than or equal to zero
df[df.revenue<=0].shape[0]
# Out:
# 0

# %%
df.head()
# Out:
#       budget     revenue                original_title  \
# 0  150000000  1513528810                Jurassic World
# 1  150000000   378436354            Mad Max: Fury Road
# 2  110000000   295238201                     Insurgent
# 3  200000000  2068178225  Star Wars: The Force Awakens
# 4  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime  \
# 0              The park is open.      124
# 1             What a Lovely Day.      120
# 2     One Choice Can Destroy You      119
# ...

# %%
#Convert release date type from string to datetime 
df.release_date = pd.to_datetime(df.release_date)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3572 entries, 0 to 10848
# Data columns (total 10 columns):
# budget            3572 non-null int64
# revenue           3572 non-null int64
# original_title    3572 non-null object
# cast              3572 non-null object
# director          3572 non-null object
# tagline           3572 non-null object
# runtime           3572 non-null int64
# genres            3572 non-null object
# release_date      3572 non-null datetime64[ns]
# release_year      3572 non-null int64
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 307.0+ KB

# %% [markdown]
# # Perform EDA

# %%
df.describe()
# Out:
#              budget       revenue      runtime  release_year
# count  3.572000e+03  3.572000e+03  3572.000000   3572.000000
# mean   3.871475e+07  1.138337e+08   109.122900   2001.178891
# std    4.294326e+07  1.808765e+08    19.686816     11.297047
# min    1.000000e+00  2.000000e+00    26.000000   1960.000000
# 25%    1.000000e+07  1.579268e+07    96.000000   1995.000000
# 50%    2.500000e+07  5.000625e+07   106.000000   2004.000000
# 75%    5.000000e+07  1.337272e+08   119.000000   2010.000000
# max    4.250000e+08  2.781506e+09   338.000000   2015.000000

# %%
#function to find Maximum and minimum values in column
def max_ (column1):
  return(df.original_title[df[column1]==df[column1].max()],df[column1][df[column1]==df[column1]].max())
#function to find Minimum and minimum values in column
def min_(column1):
    return(df.original_title[df[column1]==df[column1].min()],df[column1][df[column1]==df[column1]].min())

# %% [markdown]
# # Research Question 1 (What is the the original title of the Movie with Maximum and Minimum budget?)

# %%
#Movies with the Maximum and Minimum budget
print("The original title of the Movie with Maximum budget and its budget = {} \n ".format(max_("budget")))
print("The original title of the Movies with Minimum budget are and there budget = {} \n ".format(min_("budget")))
# Out:
# The original title of the Movie with Maximum budget and its budget = (2244    The Warrior's Way
# Name: original_title, dtype: object, 425000000)
#
# The original title of the Movies with Minimum budget are and there budget = (2618               Lost & Found
# 3581    Love, Wedding, Marriage
# Name: original_title, dtype: object, 1)

# %% [markdown]
# Now we known that the Movie with Maximum budget is"The Warrior's Way" and its budget = 425000000
# Now we known that the Movie with Minimum budget are"Lost & Found" and "Love, Wedding, Marriag", and there budgets = 1

# %% [markdown]
# # Research Question 2  (What is the the original title of the Movie with Maximum and Minimum revenue?)

# %%
#Movies with the Maximum and Minimum revenue	
print("The original title of the Movie with Maximum revenue and its revenue = {} \n ".format(max_("revenue")))
print("The original title of the Movies with Minimum revenue and there revenue = {} \n ".format(min_("revenue")))
# Out:
# The original title of the Movie with Maximum revenue and its revenue = (1386    Avatar
# Name: original_title, dtype: object, 2781505847)
#
# The original title of the Movies with Minimum revenue and there revenue = (8142    Mallrats
# Name: original_title, dtype: object, 2)

# %% [markdown]
# Now we known that the Movie with Maximum revenue is"Avatar" and its revenue = 278150587
# Now we known that the Movie with Minimum revenue is "Mallrats" and there revenue = 2

# %% [markdown]
# # Research Question 3  (What is the the original title of the Movie with Maximum and Minimum profit?)

# %%
#Calculate the profit of each Movie and insert it to third column
df.insert(2,'profit',df['revenue']-df['budget']) 
df.head()
# Out:
#       budget     revenue      profit                original_title  \
# 0  150000000  1513528810  1363528810                Jurassic World
# 1  150000000   378436354   228436354            Mad Max: Fury Road
# 2  110000000   295238201   185238201                     Insurgent
# 3  200000000  2068178225  1868178225  Star Wars: The Force Awakens
# 4  190000000  1506249360  1316249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime  \
# 0              The park is open.      124
# 1             What a Lovely Day.      120
# ...

# %%
#Movies with Maximim and Minimum profit
print("The original title of the Movie with Maximum profit and its profit = {} \n ".format(max_("profit")))
print("The original title of the Movies with Minimum profit and there profit = {} \n ".format(min_("profit")))
# Out:
# The original title of the Movie with Maximum profit and its profit = (1386    Avatar
# Name: original_title, dtype: object, 2544505847)
#
# The original title of the Movies with Minimum profit and there profit = (2244    The Warrior's Way
# Name: original_title, dtype: object, -413912431)

# %% [markdown]
# Now we known that the Movie with Maximum profit is "Avatar" and its profit = 2544505847. We also known that the Movie with Minimum profit is "The Warrior's Way" and there profit = -413912431

# %% [markdown]
# # Research Question 4  (What is the the original title of the Movie with Maximum and Minimum runtime?)

# %%
#Movies with the Maximum and Minimum runtime
print("The original title of the Movie with Maximum runtime and its runtime = {} \n ".format(max_("runtime")))
print("The original title of the Movies with Minimum runtime and there runtime = {} \n ".format(min_("runtime")))
# Out:
# The original title of the Movie with Maximum runtime and its runtime = (2107    Carlos
# Name: original_title, dtype: object, 338)
#
# The original title of the Movies with Minimum runtime and there runtime = (8005    Mickey's Christmas Carol
# Name: original_title, dtype: object, 26)

# %% [markdown]
# Now we known that the Movie with Maximum runtime is "Carlos" and its runtime = 338. We also known that the Movie with Minimum runtime is "Mickey's Christmas Carol" and there runtime = 26.

# %%
#plotting a histogram of runtime of movies
import matplotlib.pyplot as pt
pt.figure(figsize=(10,12))
 
pt.xlabel('Runtime of the Movies', fontsize = 15)
 
pt.ylabel('Number of Movies', fontsize=15)

pt.title('Movie Runtimes', fontsize=20)

pt.hist(df['runtime'],rwidth=0.6 ,bins =40)
pt.show()

# %% [markdown]
# # Research Question 5  (Which genre has the highest and lowest number of movies ?)

# %%
def highest_lowest(column):
   no = pd.Series(df[column].str.cat(sep = '|').split('|')).value_counts(ascending = False)
   return (no)

# %%
# concat all the data with | from the whole column then split it using | and count the number of times it occured. 
genre_=highest_lowest("genres")
genre_
# Out:
# Drama              1572
# Comedy             1255
# Thriller           1149
# Action             1046
# Adventure           720
# Crime               614
# Romance             595
# Science Fiction     505
# Horror              454
# Family              405
# Fantasy             381
# Mystery             328
# Animation           190
# Music               117
# History             112
# War                 109
# Western              49
# Documentary          26
# Foreign               8
# TV Movie              1
# dtype: int64

# %%
pt.figure(figsize=(18,20))

genre_.plot(kind='pie',fontsize =15)
# Show the plot
pt.show()

# %% [markdown]
# The genre who has the highest number of movies is "Drama"
# The genre who has the lowest number of movies "TV Movie"

# %% [markdown]
# # Research Question 6  (Which cast has the highest number of movies ?)

# %%
# concat all the data with | from the whole column then split it using | and count the number of times it occured. 
cast_=highest_lowest("cast").head(30)
cast_
# Out:
# Robert De Niro           50
# Bruce Willis             44
# Samuel L. Jackson        43
# Nicolas Cage             41
# Matt Damon               35
# Tom Hanks                34
# Sylvester Stallone       33
# Morgan Freeman           33
# Tom Cruise               33
# Johnny Depp              33
# Brad Pitt                32
# Harrison Ford            32
# Eddie Murphy             32
# Liam Neeson              30
# Robin Williams           29
# Mark Wahlberg            29
# Arnold Schwarzenegger    29
# Denzel Washington        28
# Cameron Diaz             28
# Owen Wilson              28
# Jim Carrey               27
# Keanu Reeves             27
# Julianne Moore           27
# Ewan McGregor            27
# Ben Affleck              27
# Dennis Quaid             27
# Julia Roberts            26
# Colin Farrell            26
# Adam Sandler             26
# Willem Dafoe             26
# dtype: int64

# %%
pt.figure(figsize=(18,20))

cast_.plot(kind='pie',fontsize =15)
# Show the plot
pt.show()

# %% [markdown]
# The cast who has the highest number of movies is "Robert De Niro"
# Next after Robert De Niro is "Bruce Willis"

# %% [markdown]
# # Research Question 7(Is the number of movies increases or decrease over years?)

# %%
pt.figure(figsize=(15,17))
# count the number of movies in each year and sort it
no_movies = df['release_year'].value_counts().sort_index()
#plotting the result
no_movies.plot('bar',title='Number Of Movies vs Year')

pt.xlabel('Number Of Movies',fontsize=20)

pt.ylabel('Year')
pt.show()

# %% [markdown]
# We notice that the number of movies "increases" over years.

# %% [markdown]
# # Research Question 8 (Is the profit increases or decreases over years?)¶)

# %%
#Group the Profit of each year then calculate the average
avg_profit = df.groupby('release_year')['profit'].mean()
#plotting
pt.figure(figsize=(12,10))
avg_profit.plot('line',title='Average Profit VS Years')

pt.xlabel('Year')

pt.ylabel('Profit')
# Out:
# Text(0,0.5,'Profit')

# %% [markdown]
# The profit 'increases' over years

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# > **Tip**: Finally, summarize your findings and the results that have been performed in relation to the question(s) provided at the beginning of the analysis. Summarize the results accurately, and point out where additional research can be done or where additional information could be useful.
#
# > **Tip**: Make sure that you are clear with regards to the limitations of your exploration. You should have at least 1 limitation explained clearly.
#
# > **Tip**: If you haven't done any statistical tests, do not imply any statistical conclusions. And make sure you avoid implying causation from correlation!
#
# > **Tip**: Once you are satisfied with your work here, check over your report to make sure that it is satisfies all the areas of the rubric (found on the project submission page at the end of the lesson). You should also probably remove all of the "Tips" like this one so that the presentation is as polished as possible.
#
# ## Submitting your Project
#
# > **Tip**: Before you submit your project, you need to create a .html or .pdf version of this notebook in the workspace here. To do that, run the code cell below. If it worked correctly, you should get a return code of 0, and you should see the generated .html file in the workspace directory (click on the orange Jupyter icon in the upper left).
#
# > **Tip**: Alternatively, you can download this report as .html via the **File** > **Download as** submenu, and then manually upload it into the workspace directory by clicking on the orange Jupyter icon in the upper left, then using the Upload button.
#
# > **Tip**: Once you've done this, you can submit your project by clicking on the "Submit Project" button in the lower right here. This will create and submit a zip file with this .ipynb doc and the .html or .pdf version you created. Congratulations!

# %% [markdown]
# # Conclution:
#     - Now we known that the Movie with Maximum budget is"The Warrior's Way" and its budget = 425000000 .We also known that the Movie with Minimum budget are"Lost & Found" and "Love, Wedding, Marriag", and there budgets = 1
#     - Now we known that the Movie with Maximum revenue is"Avatar" and its revenue = 278150587 .We also known that the Movie      with Minimum revenue is "Mallrats" and there revenue = 2
#     -Now we known that the Movie with Maximum profit is "Avatar" and its profit = 2544505847. We also known that the Movie with  Minimum profit is "The Warrior's Way" and there profit = -413912431
#     -Now we known that the Movie with Maximum runtime is "Carlos" and its runtime = 338. We also known that the Movie with    Minimum runtime is "Mickey's Christmas Carol" and there runtime = 26.
#     - The genre who has the highest number of movies is "Drama" ,The genre who has the lowest number of movies "TV Movie".
#     -The cast who has the highest number of movies is "Robert De Niro" ,Next after Robert De Niro is "Bruce Willis".
#     -We notice that the number of movies "increases" over years.
#     -The profit 'increases' over years.

# %% [markdown]
# # limitations :
#     -We are not sure if the data provided to us is completed correct and up-to-date.
#     -Dropping duplicated rows and rows with missing values may affect the overall analysis.
#     -Budget and Revenue columns don't have currency unit it may different according to the country

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
# Out:
# 0
